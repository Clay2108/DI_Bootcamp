# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("2023-2024 NBA Player Stats - Regular.csv", encoding='latin1')
df
# Out:
#     Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS
# 0    1;Precious Achiuwa;PF-C;24;TOT;74;18;21.9;3.2;...
# 1    1;Precious Achiuwa;C;24;TOR;25;0;17.5;3.1;6.8;...
# 2    1;Precious Achiuwa;PF;24;NYK;49;18;24.2;3.2;6....
# 3    2;Bam Adebayo;C;26;MIA;71;71;34;7.5;14.3;0.521...
# 4    3;Ochai Agbaji;SG;23;TOT;78;28;21;2.3;5.6;0.41...
# ..                                                 ...
# 730  568;Thaddeus Young;PF;35;PHO;10;0;8.9;1.1;2.1;...
# 731  569;Trae Young;PG;25;ATL;54;54;36;8;18.7;0.43;...
# 732  570;Omer Yurtseven;C;25;UTA;48;12;11.4;2.1;3.8...
# 733  571;Cody Zeller;C;31;NOP;43;0;7.4;0.6;1.4;0.41...
# 734  572;Ivica Zubac;C;26;LAC;68;68;26.4;5;7.6;0.64...
#
# [735 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS'], dtype='object')

# %%
df.head(5) # Display the first 5 rows of the DataFrame
# Out:
#   Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS
# 0  1;Precious Achiuwa;PF-C;24;TOT;74;18;21.9;3.2;...
# 1  1;Precious Achiuwa;C;24;TOR;25;0;17.5;3.1;6.8;...
# 2  1;Precious Achiuwa;PF;24;NYK;49;18;24.2;3.2;6....
# 3  2;Bam Adebayo;C;26;MIA;71;71;34;7.5;14.3;0.521...
# 4  3;Ochai Agbaji;SG;23;TOT;78;28;21;2.3;5.6;0.41...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735 entries, 0 to 734
# Data columns (total 1 columns):
#  #   Column                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                            --------------  -----
#  0   Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS  735 non-null    object
# dtypes: object(1)
# memory usage: 5.9+ KB

# %%
df.describe()  # Get a statistical summary of the DataFrame
# Out:
#        Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS
# count                                                 735
# unique                                                735
# top     572;Ivica Zubac;C;26;LAC;68;68;26.4;5;7.6;0.64...
# freq                                                    1

# %%
df.tail(5)  # Display the last 5 rows of the DataFrame
# Out:
#     Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS
# 730  568;Thaddeus Young;PF;35;PHO;10;0;8.9;1.1;2.1;...
# 731  569;Trae Young;PG;25;ATL;54;54;36;8;18.7;0.43;...
# 732  570;Omer Yurtseven;C;25;UTA;48;12;11.4;2.1;3.8...
# 733  571;Cody Zeller;C;31;NOP;43;0;7.4;0.6;1.4;0.41...
# 734  572;Ivica Zubac;C;26;LAC;68;68;26.4;5;7.6;0.64...

# %%
df=pd.read_csv('Housing.csv', encoding='utf-8')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7229300521  20141013T000000  231300.0         2       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000   231300.0         2       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()  # Get a statistical summary of the DataFrame
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580306e+09  5.400886e+05      3.370795      2.114757   2079.899736
# std    2.876570e+09  3.671268e+05      0.930105      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.tail(5)  # Display the last 5 rows of the DataFrame
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df2=df[['price', 'bathrooms', 'bedrooms', 'grade']]
df2.head(10)  # Display the first 10 rows of the selected columns
# Out:
#        price  bathrooms  bedrooms  grade
# 0   231300.0       1.00         2      7
# 1   538000.0       2.25         3      7
# 2   180000.0       1.00         2      6
# 3   604000.0       3.00         4      7
# 4   510000.0       2.00         3      8
# 5  1225000.0       4.50         4     11
# 6   257500.0       2.25         3      7
# 7   291850.0       1.50         3      7
# 8   229500.0       1.00         3      7
# 9   323000.0       2.50         3      7

# %%
df3=df2.drop(['bathrooms'], axis=1)  # Drop the 'bathrooms' column from df2 
df3.head(10)  # Display the first 10 rows of the DataFrame after dropping the 'bathrooms' column
# Out:
#        price  bedrooms  grade
# 0   231300.0         2      7
# 1   538000.0         3      7
# 2   180000.0         2      6
# 3   604000.0         4      7
# 4   510000.0         3      8
# 5  1225000.0         4     11
# 6   257500.0         3      7
# 7   291850.0         3      7
# 8   229500.0         3      7
# 9   323000.0         3      7

# %%
# extract one column from df3
bathrooms= df['bathrooms']
df3['bathrooms'] = bathrooms*2 
df3.head(10)  # Display the first 10 rows of the DataFrame after adding the 'bathrooms' column
# Out:
#        price  bedrooms  grade  bathrooms
# 0   231300.0         2      7        2.0
# 1   538000.0         3      7        4.5
# 2   180000.0         2      6        2.0
# 3   604000.0         4      7        6.0
# 4   510000.0         3      8        4.0
# 5  1225000.0         4     11        9.0
# 6   257500.0         3      7        4.5
# 7   291850.0         3      7        3.0
# 8   229500.0         3      7        2.0
# 9   323000.0         3      7        5.0

# %%
#filer data
results= df2[df2['grade'] <= 5] 
results.head(10)  # Display the first 10 rows of the filtered DataFrame
# Out:
#         price  bathrooms  bedrooms  grade
# 36   550000.0       1.00         4      5
# 166  269950.0       1.75         2      5
# 263  425000.0       1.00         2      5
# 264  369900.0       0.75         1      5
# 350  299000.0       0.75         1      4
# 411  517534.0       1.00         2      5
# 465   80000.0       0.75         1      4
# 478  315000.0       1.00         2      5
# 523  235000.0       1.50         4      5
# 700  795000.0       1.00         2      5

# %%
#plot price vs grade
plt.scatter(df2['price'], df2['grade'])
plt.xlabel('Price')
plt.ylabel('Grade')
plt.title('Price vs Grade')
plt.show()

# %%
df=pd.read_csv('all_seasons.csv', encoding='utf-8')  # Load a new dataset
df
# Out:
#        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0               0  Randy Livingston               HOU  22.0         193.04
# 1               1  Gaylon Nickerson               WAS  28.0         190.50
# 2               2      George Lynch               VAN  26.0         203.20
# 3               3    George McCloud               LAL  30.0         203.20
# 4               4      George Zidek               DEN  23.0         213.36
# ...           ...               ...               ...   ...            ...
# 12839       12839       Joel Embiid               PHI  29.0         213.36
# 12840       12840   John Butler Jr.               POR  20.0         213.36
# 12841       12841      John Collins               ATL  25.0         205.74
# 12842       12842      Jericho Sims               NYK  24.0         208.28
# 12843       12843    JaMychal Green               GSW  33.0         205.74
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0           0  Randy Livingston               HOU  22.0         193.04
# 1           1  Gaylon Nickerson               WAS  28.0         190.50
# 2           2      George Lynch               VAN  26.0         203.20
# 3           3    George McCloud               LAL  30.0         203.20
# 4           4      George Zidek               DEN  23.0         213.36
# 5           5    Gerald Wilkins               ORL  33.0         198.12
# 6           6  Gheorghe Muresan               WAS  26.0         231.14
# 7           7         Glen Rice               CHH  30.0         203.20
# 8           8    Glenn Robinson               MIL  24.0         200.66
# 9           9        Grant Hill               DET  24.0         203.20
#
#    player_weight                college country draft_year draft_round  ...  \
# 0      94.800728        Louisiana State     USA       1996           2  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12844 entries, 0 to 12843
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         12844 non-null  int64
#  1   player_name        12844 non-null  object
#  2   team_abbreviation  12844 non-null  object
#  3   age                12844 non-null  float64
#  4   player_height      12844 non-null  float64
#  5   player_weight      12844 non-null  float64
#  6   college            10990 non-null  object
#  7   country            12844 non-null  object
#  8   draft_year         12844 non-null  object
#  9   draft_round        12844 non-null  object
#  10  draft_number       12844 non-null  object
#  11  gp                 12844 non-null  int64
#  12  pts                12844 non-null  float64
#  13  reb                12844 non-null  float64
#  14  ast                12844 non-null  float64
#  15  net_rating         12844 non-null  float64
# ...

# %%
df.describe()  # Get a statistical summary of the DataFrame
# Out:
#          Unnamed: 0           age  player_height  player_weight            gp  \
# count  12844.000000  12844.000000   12844.000000   12844.000000  12844.000000
# mean    6421.500000     27.045313     200.555097     100.263279     51.154158
# std     3707.887763      4.339211       9.111090      12.426628     25.084904
# min        0.000000     18.000000     160.020000      60.327736      1.000000
# 25%     3210.750000     24.000000     193.040000      90.718400     31.000000
# 50%     6421.500000     26.000000     200.660000      99.790240     57.000000
# 75%     9632.250000     30.000000     208.280000     108.862080     73.000000
# max    12843.000000     44.000000     231.140000     163.293120     85.000000
#
#                 pts           reb           ast    net_rating      oreb_pct  \
# count  12844.000000  12844.000000  12844.000000  12844.000000  12844.000000
# mean       8.212582      3.558486      1.824681     -2.226339      0.054073
# ...

# %%
df.tail(5)  # Display the last 5 rows of the DataFrame
# Out:
#        Unnamed: 0      player_name team_abbreviation   age  player_height  \
# 12839       12839      Joel Embiid               PHI  29.0         213.36
# 12840       12840  John Butler Jr.               POR  20.0         213.36
# 12841       12841     John Collins               ATL  25.0         205.74
# 12842       12842     Jericho Sims               NYK  24.0         208.28
# 12843       12843   JaMychal Green               GSW  33.0         205.74
#
#        player_weight        college   country draft_year draft_round  ...  \
# 12839     127.005760         Kansas  Cameroon       2014           1  ...
# 12840      86.182480  Florida State       USA  Undrafted   Undrafted  ...
# 12841     102.511792    Wake Forest       USA       2017           1  ...
# 12842     113.398000          Texas       USA       2021           2  ...
# 12843     102.965384        Alabama       USA  Undrafted   Undrafted  ...
#
#         pts   reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# ...

# %%
df2=df[['player_name', 'draft_year', 'team_abbreviation', 'pts', 'age']]
df2.head(10)  # Display the first 10 rows of the selected columns
# Out:
#         player_name draft_year team_abbreviation   pts   age
# 0  Randy Livingston       1996               HOU   3.9  22.0
# 1  Gaylon Nickerson       1994               WAS   3.8  28.0
# 2      George Lynch       1993               VAN   8.3  26.0
# 3    George McCloud       1989               LAL  10.2  30.0
# 4      George Zidek       1995               DEN   2.8  23.0
# 5    Gerald Wilkins       1985               ORL  10.6  33.0
# 6  Gheorghe Muresan       1993               WAS  10.6  26.0
# 7         Glen Rice       1989               CHH  26.8  30.0
# 8    Glenn Robinson       1994               MIL  21.1  24.0
# 9        Grant Hill       1994               DET  21.4  24.0

# %%
df3=df2.drop(['age'], axis=1)  # Drop the 'age' column from df2
df3.head(10)  # Display the first 10 rows of the DataFrame after
# Out:
#         player_name draft_year team_abbreviation   pts
# 0  Randy Livingston       1996               HOU   3.9
# 1  Gaylon Nickerson       1994               WAS   3.8
# 2      George Lynch       1993               VAN   8.3
# 3    George McCloud       1989               LAL  10.2
# 4      George Zidek       1995               DEN   2.8
# 5    Gerald Wilkins       1985               ORL  10.6
# 6  Gheorghe Muresan       1993               WAS  10.6
# 7         Glen Rice       1989               CHH  26.8
# 8    Glenn Robinson       1994               MIL  21.1
# 9        Grant Hill       1994               DET  21.4

# %%
pts= df['pts']
df3['pts'] = pts*2
df3.head(10)  # Display the first 10 rows of the DataFrame after adding the 'pts' column
# Out:
#         player_name draft_year team_abbreviation   pts
# 0  Randy Livingston       1996               HOU   7.8
# 1  Gaylon Nickerson       1994               WAS   7.6
# 2      George Lynch       1993               VAN  16.6
# 3    George McCloud       1989               LAL  20.4
# 4      George Zidek       1995               DEN   5.6
# 5    Gerald Wilkins       1985               ORL  21.2
# 6  Gheorghe Muresan       1993               WAS  21.2
# 7         Glen Rice       1989               CHH  53.6
# 8    Glenn Robinson       1994               MIL  42.2
# 9        Grant Hill       1994               DET  42.8

# %%
result=df3[df3['pts'] >= 20]  # Filter the DataFrame to include only rows where 'pts' is greater than or equal to 20
result.head(10)  # Display the first 10 rows of the filtered DataFrame
# Out:
#          player_name draft_year team_abbreviation   pts
# 3     George McCloud       1989               LAL  20.4
# 5     Gerald Wilkins       1985               ORL  21.2
# 6   Gheorghe Muresan       1993               WAS  21.2
# 7          Glen Rice       1989               CHH  53.6
# 8     Glenn Robinson       1994               MIL  42.2
# 9         Grant Hill       1994               DET  42.8
# 10        Gary Trent       1995               POR  21.6
# 18   Hakeem Olajuwon       1984               HOU  46.4
# 22       Gary Payton       1990               SEA  43.6
# 37     Eric Williams       1995               BOS  30.0

# %%
# plot player points vs age
plt.scatter(df['age'], df['pts'])
plt.xlabel('age')
plt.ylabel('Points')
plt.title('Age vs Points')
plt.show()

# %%
df3.head(10)  # Display the first 10 rows of the DataFrame after all operations
# Out:
#         player_name draft_year team_abbreviation   pts
# 0  Randy Livingston       1996               HOU   7.8
# 1  Gaylon Nickerson       1994               WAS   7.6
# 2      George Lynch       1993               VAN  16.6
# 3    George McCloud       1989               LAL  20.4
# 4      George Zidek       1995               DEN   5.6
# 5    Gerald Wilkins       1985               ORL  21.2
# 6  Gheorghe Muresan       1993               WAS  21.2
# 7         Glen Rice       1989               CHH  53.6
# 8    Glenn Robinson       1994               MIL  42.2
# 9        Grant Hill       1994               DET  42.8

# %%
row1=df3.iloc[0]  # Get the first row of df3
row1
# Out:
# player_name          Randy Livingston
# draft_year                       1996
# team_abbreviation                 HOU
# pts                               7.8
# Name: 0, dtype: object

# %%
player_name = df2['player_name']
player_name.head(10)  # Display the first 10 player names
# Out:
# 0    Randy Livingston
# 1    Gaylon Nickerson
# 2        George Lynch
# 3      George McCloud
# 4        George Zidek
# 5      Gerald Wilkins
# 6    Gheorghe Muresan
# 7           Glen Rice
# 8      Glenn Robinson
# 9          Grant Hill
# Name: player_name, dtype: object

# %%
df3.isna() # Check for missing values in the DataFrame
# Out:
#        player_name  draft_year  team_abbreviation    pts
# 0            False       False              False  False
# 1            False       False              False  False
# 2            False       False              False  False
# 3            False       False              False  False
# 4            False       False              False  False
# ...            ...         ...                ...    ...
# 12839        False       False              False  False
# 12840        False       False              False  False
# 12841        False       False              False  False
# 12842        False       False              False  False
# 12843        False       False              False  False
#
# [12844 rows x 4 columns]

# %%
df.fillna(value=0, inplace=True) 
df
# Out:
#        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0               0  Randy Livingston               HOU  22.0         193.04
# 1               1  Gaylon Nickerson               WAS  28.0         190.50
# 2               2      George Lynch               VAN  26.0         203.20
# 3               3    George McCloud               LAL  30.0         203.20
# 4               4      George Zidek               DEN  23.0         213.36
# ...           ...               ...               ...   ...            ...
# 12839       12839       Joel Embiid               PHI  29.0         213.36
# 12840       12840   John Butler Jr.               POR  20.0         213.36
# 12841       12841      John Collins               ATL  25.0         205.74
# 12842       12842      Jericho Sims               NYK  24.0         208.28
# 12843       12843    JaMychal Green               GSW  33.0         205.74
#
# ...

# %%
# Calculate the mean of the 'pts' column
mean_pts = df['pts'].mean()
print("Mean points:", mean_pts)

# Display the DataFrame
# Out:
# Mean points: 8.212581750233571

# %%
df.head(5)  # Display the first 10 rows of the DataFrame
# Out:
#    Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0           0  Randy Livingston               HOU  22.0         193.04
# 1           1  Gaylon Nickerson               WAS  28.0         190.50
# 2           2      George Lynch               VAN  26.0         203.20
# 3           3    George McCloud               LAL  30.0         203.20
# 4           4      George Zidek               DEN  23.0         213.36
#
#    player_weight                college country draft_year draft_round  ...  \
# 0      94.800728        Louisiana State     USA       1996           2  ...
# 1      86.182480  Northwestern Oklahoma     USA       1994           2  ...
# 2     103.418976         North Carolina     USA       1993           1  ...
# 3     102.058200          Florida State     USA       1989           1  ...
# 4     119.748288                   UCLA     USA       1995           1  ...
#
#     pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct  \
# ...

# %%
df['reb'].sum()  # Calculate the sum of the 'reb' column
# Out:
# np.float64(45705.2)

# %%
df.nlargest(3, 'pts')  # Get the top 3 rows with the highest 'pts' values
# Out:
#        Unnamed: 0   player_name team_abbreviation   age  player_height  \
# 10227       10227  James Harden               HOU  29.0         195.58
# 4163         4163   Kobe Bryant               LAL  27.0         198.12
# 10634       10634  James Harden               HOU  30.0         195.58
#
#        player_weight        college country draft_year draft_round  ...   pts  \
# 10227       99.79024  Arizona State     USA       2009           1  ...  36.1
# 4163        99.79024              0     USA       1996           1  ...  35.4
# 10634       99.79024  Arizona State     USA       2009           1  ...  34.3
#
#        reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct  \
# 10227  6.6  7.5         6.3     0.023     0.157    0.396   0.616    0.394
# 4163   5.3  4.5         4.7     0.026     0.127    0.384   0.559    0.228
# 10634  6.6  7.5         5.8     0.026     0.139    0.356   0.626    0.366
#
#         season
# 10227  2018-19
# 4163   2005-06
# 10634  2019-20
# ...

# %%
# Access the 'pts' value for Kobe Bryant from df2
kobe_pts = df2.loc[df2['player_name'] == 'Kobe Bryant', 'pts']
print(kobe_pts)
# Out:
# 334      7.6
# 496     15.4
# 1225    19.9
# 1413    22.5
# 1882    28.5
# 2445    25.2
# 2718    30.0
# 3440    24.0
# 3569    27.6
# 4163    35.4
# 4817    31.6
# 5201    28.3
# 5420    26.8
# 6144    27.0
# 6297    25.3
# 6763    27.9
# 7576    27.3
# 8021    13.8
# 8516    22.3
# 8961    17.6
# Name: pts, dtype: float64

# %%
df
# Out:
#        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0               0  Randy Livingston               HOU  22.0         193.04
# 1               1  Gaylon Nickerson               WAS  28.0         190.50
# 2               2      George Lynch               VAN  26.0         203.20
# 3               3    George McCloud               LAL  30.0         203.20
# 4               4      George Zidek               DEN  23.0         213.36
# ...           ...               ...               ...   ...            ...
# 12839       12839       Joel Embiid               PHI  29.0         213.36
# 12840       12840   John Butler Jr.               POR  20.0         213.36
# 12841       12841      John Collins               ATL  25.0         205.74
# 12842       12842      Jericho Sims               NYK  24.0         208.28
# 12843       12843    JaMychal Green               GSW  33.0         205.74
#
# ...

# %%
df3
# Out:
#             player_name draft_year team_abbreviation   pts
# 0      Randy Livingston       1996               HOU   7.8
# 1      Gaylon Nickerson       1994               WAS   7.6
# 2          George Lynch       1993               VAN  16.6
# 3        George McCloud       1989               LAL  20.4
# 4          George Zidek       1995               DEN   5.6
# ...                 ...        ...               ...   ...
# 12839       Joel Embiid       2014               PHI  66.2
# 12840   John Butler Jr.  Undrafted               POR   4.8
# 12841      John Collins       2017               ATL  26.2
# 12842      Jericho Sims       2021               NYK   6.8
# 12843    JaMychal Green  Undrafted               GSW  12.8
#
# [12844 rows x 4 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0               0  Randy Livingston               HOU  22.0         193.04
# 1               1  Gaylon Nickerson               WAS  28.0         190.50
# 2               2      George Lynch               VAN  26.0         203.20
# 3               3    George McCloud               LAL  30.0         203.20
# 4               4      George Zidek               DEN  23.0         213.36
# ...           ...               ...               ...   ...            ...
# 12839       12839       Joel Embiid               PHI  29.0         213.36
# 12840       12840   John Butler Jr.               POR  20.0         213.36
# 12841       12841      John Collins               ATL  25.0         205.74
# 12842       12842      Jericho Sims               NYK  24.0         208.28
# 12843       12843    JaMychal Green               GSW  33.0         205.74
#
# ...

# %%
df.info()  # Display DataFrame information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12844 entries, 0 to 12843
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         12844 non-null  int64
#  1   player_name        12844 non-null  object
#  2   team_abbreviation  12844 non-null  object
#  3   age                12844 non-null  float64
#  4   player_height      12844 non-null  float64
#  5   player_weight      12844 non-null  float64
#  6   college            12844 non-null  object
#  7   country            12844 non-null  object
#  8   draft_year         12844 non-null  object
#  9   draft_round        12844 non-null  object
#  10  draft_number       12844 non-null  object
#  11  gp                 12844 non-null  int64
#  12  pts                12844 non-null  float64
#  13  reb                12844 non-null  float64
#  14  ast                12844 non-null  float64
#  15  net_rating         12844 non-null  float64
# ...

# %%
df2.columns
# Out:
# Index(['player_name', 'draft_year', 'team_abbreviation', 'pts', 'age'], dtype='object')

# %%
df=pd.read_csv('all_seasons.csv', encoding='utf-8')  # Load a new dataset
df
# Out:
#        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 0               0  Randy Livingston               HOU  22.0         193.04
# 1               1  Gaylon Nickerson               WAS  28.0         190.50
# 2               2      George Lynch               VAN  26.0         203.20
# 3               3    George McCloud               LAL  30.0         203.20
# 4               4      George Zidek               DEN  23.0         213.36
# ...           ...               ...               ...   ...            ...
# 12839       12839       Joel Embiid               PHI  29.0         213.36
# 12840       12840   John Butler Jr.               POR  20.0         213.36
# 12841       12841      John Collins               ATL  25.0         205.74
# 12842       12842      Jericho Sims               NYK  24.0         208.28
# 12843       12843    JaMychal Green               GSW  33.0         205.74
#
# ...

# %%
df.columns  # Display the columns of the DataFrame
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
df2= df[['player_name', 'age','college', 'draft_number', 'team_abbreviation', 'pts']]
df2.tail(50) # Display the last 50 rows of the selected columns
# Out:
#                   player_name   age                    college draft_number  \
# 12794            Jakob Poeltl  27.0                       Utah            9
# 12795              Jack White  25.0                       Duke    Undrafted
# 12796             Isaiah Roby  25.0                   Nebraska           45
# 12797            Jaxson Hayes  23.0                      Texas            8
# 12798              Jay Scrubb  22.0              John A. Logan           55
# 12799       Jonas Valanciunas  31.0                        NaN            5
# 12800          Jonathan Isaac  25.0              Florida State            6
# 12801        Jonathan Kuminga  20.0                        NaN            7
# 12802         Jordan Clarkson  31.0                   Missouri           46
# 12803          Jordan Goodwin  24.0                  St. Louis    Undrafted
# 12804             Jordan Hall  21.0          St. Joseph's (PA)    Undrafted
# ...

# %%
# i want draft number in range 1 to 3 from df2
draft_number_numeric = pd.to_numeric(df2['draft_number'], errors='coerce')
draft_range = df2[(draft_number_numeric >= 1) & (draft_number_numeric <= 3)]
draft_range.tail(30)  # Display the first 10 rows of the filtered DataFrame
# Out:
#               player_name   age              college draft_number  \
# 12476        Derrick Rose  34.0              Memphis            1
# 12513       Deandre Ayton  24.0              Arizona            1
# 12551         Evan Mobley  22.0  Southern California            3
# 12571         Ben Simmons  26.0      Louisiana State            1
# 12574       Blake Griffin  34.0             Oklahoma            1
# 12582        Bradley Beal  30.0              Florida            3
# 12584     Anthony Edwards  21.0              Georgia            1
# 12585       Anthony Davis  30.0             Kentucky            1
# 12587      Andrew Wiggins  28.0               Kansas            1
# 12596          Al Horford  37.0              Florida            3
# 12610      Brandon Ingram  25.0                 Duke            2
# 12626    D'Angelo Russell  27.0           Ohio State            2
# 12642     Cade Cunningham  21.0       Oklahoma State            1
# ...

# %%
draft_range.describe()  # Get a statistical summary of the filtered DataFrame
# Out:
#                age          pts
# count  1027.000000  1027.000000
# mean     27.723466    14.756183
# std       5.026001     7.197126
# min      19.000000     0.000000
# 25%      24.000000     9.200000
# 50%      27.000000    14.100000
# 75%      31.000000    20.000000
# max      40.000000    36.100000

# %%
# Access the 34th row by position (not by index label)
draft_range.iloc[905]
# Out:
# player_name          Deandre Ayton
# age                           21.0
# college                    Arizona
# draft_number                     1
# team_abbreviation              PHX
# pts                           18.2
# Name: 10945, dtype: object

# %%
draft_range.info
# Out:
# <bound method DataFrame.info of             player_name   age         college draft_number team_abbreviation  \
# 8        Glenn Robinson  24.0          Purdue            1               MIL
# 9            Grant Hill  24.0            Duke            3               DET
# 18      Hakeem Olajuwon  34.0         Houston            1               HOU
# 22          Gary Payton  28.0    Oregon State            2               SEA
# 51     Jerry Stackhouse  22.0  North Carolina            3               PHI
# ...                 ...   ...             ...          ...               ...
# 12783  Jabari Smith Jr.  20.0          Auburn            3               HOU
# 12820         John Wall  32.0        Kentucky            1               LAC
# 12822      Jaylen Brown  26.0      California            3               BOS
# 12825      Jayson Tatum  25.0            Duke            3               BOS
# 12839       Joel Embiid  29.0          Kansas            3               PHI
#
#         pts
# ...

# %%
draft_range.isna().sum() # Check for missing values in the DataFrame
# Out:
# player_name            0
# age                    0
# college              135
# draft_number           0
# team_abbreviation      0
# pts                    0
# dtype: int64

# %%
print (draft_range['college'].unique())
draft_range['college'].value_counts().tail(50)  # Count occurrences of each unique value in the 'college' column
# Out:
# ['Purdue' 'Duke' 'Houston' 'Oregon State' 'North Carolina' 'Maryland'
#  'California' 'Michigan' 'Pittsburgh' 'Georgia' 'Syracuse' 'Kansas' 'Navy'
#  'Arizona' 'Louisiana State' 'Brigham Young' 'Marist' 'Oklahoma' 'DePaul'
#  'Massachusetts' 'Georgia Tech' 'Nevada-Las Vegas' 'Georgetown'
#  'Louisville' 'Alabama' 'Creighton' 'Memphis' 'Utah' 'Wake Forest'
#  'Colorado' 'Pacific' 'UCLA' 'Cincinnati' nan 'Connecticut' 'Illinois'
#  'Gonzaga' 'Texas' 'Florida' 'Ohio State' 'Kansas State'
#  'Southern California' 'Arizona State' 'Kentucky' 'Indiana' 'Washington'
#  ' ' 'Murray State' 'University of Texas at Austin' 'Texas-Austin'
#  'Oklahoma State' 'Auburn']
# college
# Kentucky                         44
# Georgetown                       41
# California                       36
# North Carolina                   36
# Syracuse                         33
# Kansas                           33
# Louisiana State                  32
# Arizona                          31
# ...

# %%
sum_college_counts = (draft_range['college'] == 'North Carolina').sum()
print("Number of players from North Carolina:", sum_college_counts)
# Out:
# Number of players from North Carolina: 36

# %%
# Group by 'college' and count the number of players from each college
college_counts = draft_range.groupby('college').size()
college_counts
# Out:
# college
#                                    2
# Alabama                           14
# Arizona                           31
# Arizona State                     14
# Auburn                             1
# Brigham Young                      9
# California                        36
# Cincinnati                        15
# Colorado                          17
# Connecticut                       26
# Creighton                          4
# DePaul                             4
# Duke                             117
# Florida                           27
# Georgetown                        41
# Georgia                            5
# Georgia Tech                      21
# Gonzaga                            3
# Houston                            6
# Illinois                          12
# Indiana                           10
# Kansas                            33
# Kansas State                      11
# Kentucky                          44
# Louisiana State                   32
# ...

# %%
draft_range.tail(10)
# Out:
#             player_name   age        college draft_number team_abbreviation  \
# 12740       Luka Doncic  24.0            NaN            3               DAL
# 12760      James Harden  33.0  Arizona State            3               PHI
# 12762     James Wiseman  22.0        Memphis            2               DET
# 12772       Jalen Green  21.0            NaN            2               HOU
# 12781         Ja Morant  23.0   Murray State            2               MEM
# 12783  Jabari Smith Jr.  20.0         Auburn            3               HOU
# 12820         John Wall  32.0       Kentucky            1               LAC
# 12822      Jaylen Brown  26.0     California            3               BOS
# 12825      Jayson Tatum  25.0           Duke            3               BOS
# 12839       Joel Embiid  29.0         Kansas            3               PHI
#
#         pts
# 12740  32.4
# 12760  21.0
# 12762  10.0
# 12772  22.1
# 12781  26.2
# 12783  12.8
# 12820  11.4
# 12822  26.6
# ...

# %%
# Ensure 'draft_number' is numeric for comparison
draft_range_numeric = draft_range.copy()
draft_range_numeric['draft_number'] = pd.to_numeric(draft_range_numeric['draft_number'], errors='coerce')

Age = draft_range_numeric[(draft_range_numeric['age'] <= 20) & (draft_range_numeric['draft_number'] <= 1)]
Age.tail(30)  # Display the filtered rows where age is less than or equal to 19 and draft_number is less than or equal to 1
# Out:
#               player_name   age         college  draft_number  \
# 2443          Kwame Brown  20.0             NaN             1
# 3448         LeBron James  19.0             NaN             1
# 3616         LeBron James  20.0             NaN             1
# 3924        Dwight Howard  19.0             NaN             1
# 4353        Dwight Howard  20.0             NaN             1
# 5430         Derrick Rose  20.0         Memphis             1
# 6326            John Wall  20.0        Kentucky             1
# 6734         Kyrie Irving  20.0            Duke             1
# 7301        Anthony Davis  20.0        Kentucky             1
# 8284       Andrew Wiggins  20.0          Kansas             1
# 9003   Karl-Anthony Towns  20.0        Kentucky             1
# 9571       Markelle Fultz  20.0      Washington             1
# 10313       Deandre Ayton  20.0         Arizona             1
# 11029     Zion Williamson  19.0            Duke             1
# ...

# %%
# Convert 'draft_number' to numeric before grouping
draft_range_numeric = draft_range.copy()
draft_range_numeric['draft_number'] = pd.to_numeric(draft_range_numeric['draft_number'], errors='coerce')

df5 = draft_range_numeric.groupby('college').mean(numeric_only=True)  # Group by 'college' and calculate the mean of numeric columns
df5['draft_number'].plot(kind='line')  # Plot the mean draft number for each college
plt.xlabel('College')
plt.ylabel('Mean Draft Number')
plt.title('Mean Draft Number by College')
plt.show()

# %%
draft_range.head(10)  # Display the first 10 rows of the filtered DataFrame
# Out:
#             player_name   age         college draft_number team_abbreviation  \
# 8        Glenn Robinson  24.0          Purdue            1               MIL
# 9            Grant Hill  24.0            Duke            3               DET
# 18      Hakeem Olajuwon  34.0         Houston            1               HOU
# 22          Gary Payton  28.0    Oregon State            2               SEA
# 51     Jerry Stackhouse  22.0  North Carolina            3               PHI
# 70            Joe Smith  21.0        Maryland            1               GSW
# 90           Jason Kidd  24.0      California            2               PHX
# 104        Chris Webber  24.0        Michigan            1               WAS
# 106  Christian Laettner  27.0            Duke            3               ATL
# 131       Buck Williams  37.0        Maryland            3               NYK
#
#       pts
# 8    21.1
# 9    21.4
# 18   23.2
# 22   21.8
# 51   20.7
# 70   18.7
# 90   10.9
# 104  20.1
# 106  18.1
# ...

# %%
df7= draft_range.groupby('team_abbreviation').count()
df7.plot(kind='pie',y='draft_number')  # Plot the count of players from each college
# Out:
# <Axes: ylabel='draft_number'>
